# %%
import pandas as pd
import random
from tqdm import tqdm

# CSV 파일 로드
def load_csv(file_path):
    return pd.read_csv(file_path)

# 랜덤 단어 순서 변경 (Random Shuffle)
def random_shuffle(sentence):
    words = sentence.split()
    random.shuffle(words)
    return ' '.join(words)

# 랜덤 단어 추가 (Random Insertion)
def random_insertion(sentence, n=1):
    words = sentence.split()
    for _ in range(n):
        word = random.choice(words)
        insert_pos = random.randint(0, len(words))
        words.insert(insert_pos, word)
    return ' '.join(words)

# 랜덤 단어 삭제 (Random Deletion)
def random_deletion(sentence, p=0.2):
    words = sentence.split()
    if len(words) == 1:
        return sentence
    new_words = [word for word in words if random.uniform(0, 1) > p]
    return ' '.join(new_words) if new_words else words[random.randint(0, len(words)-1)]

# 데이터 증강 적용 (클래스 보존)
def augment_data(df, text_column='conversation', class_column='class'):
    augmented_data = []
    for _, row in tqdm(df.iterrows(), total=len(df)):
        sentence, label = row[text_column], row[class_column]
        aug_methods = [
            (random_shuffle(sentence), label),
            (random_insertion(sentence), label),
            (random_deletion(sentence), label)
        ]
        augmented_data.extend(aug_methods)
    return pd.DataFrame(augmented_data, columns=[text_column, class_column])

# CSV 저장
def save_augmented_data(df, output_path):
    df.to_csv(output_path, index=False)

# 실행 예제
if __name__ == "__main__":
    input_file = "C:/Users/양자/Desktop/Hun_Works/AIFFEL_DLthon/DLThon01/CHYeom/data/train.csv"
    output_file = "C:/Users/양자/Desktop/Hun_Works/AIFFEL_DLthon/DLThon01/CHYeom/data/augmented_train.csv"
    df = load_csv(input_file)
    augmented_df = augment_data(df, class_column='class', text_column='conversation', )
    save_augmented_data(augmented_df, output_file)
    print("텍스트 증강 완료!")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 4788/4788 [00:00<00:00, 6713.09it/s]
# 텍스트 증강 완료!

# %%
augmented_df.head(60)
# Out:
#                                          conversation  class
# 0   혼자 선택 죽여버려야겠군 휘말리게 못하겠습니다 애원하는 도와주세요 너에게는 선택해 ...      0
# 1   지금 너 스스로를 죽여달라고 애원하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 거...      0
# 2   지금 스스로를 죽여달라고 애원하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 거면 ...      0
# 3   폭발물이 . 업무방해죄에 . 장난전화는 재미있겠지 ? 들어 분 이야기했어 폭발물을 ...      0
# 4   길동경찰서입니다 . 시 분 마트에 폭발물을 설치할거다 . 네 ? 똑바로 들어 한번만...      0
# 5   길동경찰서입니다 . 시 설치할거다 . 네 똑바로 들어 한번만 더 . 장난전화 걸지 ...      0
# 6   . ? 작은데 너 귀여운거 나보다 ! . 재미없어 난쟁이들도 작은 되게 장가가고하던...      3
# 7   너 되게 귀여운거 알지 ? 나보다 작은 남자는 첨봤어 . 그만해 . 니들 그만 놀리...      3
# 8   너 되게 귀여운거 알지 ? 작은 남자는 첨봤어 . 그만해 . 놀리는거 . 너가 키 ...      3
# 9   넌 말이야 내놔 다 아니에요 너 정말 돈 너 죽는다 마지막 있나봐 . 얘 뒤져서 좀...      1
# 10  어이 거기 예 ? ? 너 말이야 너 피시방 . 이리 오라고 무슨 일 . 너 옷 좋아...      1
# 11  어이 거기 예 ? ? 너 너 . 이리 무슨 . 너 옷 좋아보인다 ? 얘 돈 좀 있나...      1
# 12  하셨잖아요 발라보세요 좋은거 내야 강매하는거 ? 선크림 누구 진짜 먼저 ? 당신이 ...      1
# 13  저기요 혹시 날이 너무 뜨겁잖아요 ? 저희 회사에서 이 선크림 파는데 한 번 손등에...      1
# 14  저기요 혹시 날이 너무 뜨겁잖아요 저희 회사에서 이 선크림 파는데 번 발라보실래요 ...      1
# 15  알겠습니다 말 이번엔 저도 . 매일같이 ? 프로젝트만 뭐 실수 해본 이러면 ! 팀 ...      2
# 16  나 이틀뒤에 가나다 음식점 예약좀 해줘 . 저녁 시로 . 가나다 음식점이요 . ? ...      2
# 17  나 이틀뒤에 가나다 음식점 예약좀 해줘 . 저녁 . 음식점이요 . ? 응 부모님한테...      2
# 18  네분명히 없는데 오늘 . 아이스커피 더우시다고 아니요 네 아가씨가잘못안거 . 어휴 ...      3
# 19  번 손님 아이스커피 두잔나왔습니다 아이스커피 ? 네 맛있게드세요 저기요 하면 아가씨...      3
# 20  손님 아이스커피 두잔나왔습니다 아이스커피 ? 네 저기요 아가씨 나는 시킨적이 없는데...      3
# 21  붙여 본드로 들어옵니다 이거 알아 당신 드렸고 인터폰도 . ? 경비아저씨 수차례 ?...      3
# 22  경비아저씨 내차에 경고장 붙였어요 ? 내가 여기 몇년째 사는데 아직도 내차인줄 모르...      3
# 23  내차에 경고장 붙였어요 ? 내가 여기 몇년째 사는데 아직도 내차인줄 모르고 이딴식으...      3
# 24  된다면서요 좀 해결해주시지 못합니다 그런겁니다 진정을 할인 저 점장님도 ? 해주던데...      3
# 25  이거 할인 된다면서요 확인해보겠습니다 아까 저 시람은 할인 해주던데 네 저 손님은 ...      3
# 26  이거 할인 된다면서요 확인해보겠습니다 아까 해주던데 네 손님은 고객님이십니다 고객을...      3
# 27  . 그게 알지 . 너무 국세청에도 수치가 거 되겠지 이 네가 그리고 ? 그래 얼마나...      1
# 28  자네 세금계산서 보내준 거 메일이랑 수치가 다르던데 ? 그게 . 얼마나 해먹었어 ?...      1
# 29  자네 세금계산서 거 수치가 다르던데 ? 그게 . 얼마나 해먹었어 ? 괜찮아 . 다른...      1
# 30  . 지금 빨리빨리 다 해라 왜 . 하나 ! 담아 빨리 찾으세요 말보르 사장은 ? ....      1
# 31  네 뭐 ? 드릴까요 ? 말보르 레드 하나 . 네 . 여기요 ! 여기 사장은 없어 ?...      1
# 32  뭐 드릴까요 하나 . 네 . 여기요 ! 사장은 없어 네 사장님 지금 안계세요 . ....      1
# 33  ? 안해놨니 안하셨는데요 뭘한거야 도대체 이대리 이게 이니 ? 아닙니다 귀 새로 ?...      2
# 34  이대리 오늘 도대체 뭘한거야 ? 창고정리도 하고 바닥도 청소했습니다 이게 열심히 한...      2
# 35  이대리 도대체 ? 창고정리도 하고 바닥도 청소했습니다 이게 한거니 열심히 했습니다 ...      2
# 36  애까지 어떻게 각오하는 애 울리면 곤란합니다 보고 되는지 들어왔는데 네 전화주셨나요...      0
# 37  남 네네 무슨 일 때문에 전화주셨나요 ? 우리 애가 지우개 하나 훔친거 가지고 애들...      0
# 38  네네 무슨 일 전화주셨나요 ? 우리 하나 훔친거 앞에서 면박줬니 ? 아니고 댁 내 ...      0
# 39  진짜로 내가 없어요 돼 줘 좀만 진짜 . 생겼으니까 어떻게 여기 많게 왜 형 ? 좀...      1
# 40  근데 형 ! 형 ! 돈좀있어 ? 저 저요 . ? 여기 형말고 누가 있어 ? 형 얼마...      1
# 41  형 ! 형 ! 돈좀있어 저 . ? 여기 형말고 누가 있어 ? 형 얼마 있어 ? 저 ...      1
# 42  김사원 대리님 ? 제가 하는데 저도 많아서요 수 ? 이거 많아서요 할 하겠습니다 있...      2
# 43  김사원 대리님 왜 그러세요 ? 이거 오늘까지 제출해야 하는데 좀 해줄래 ? 네 ? ...      2
# 44  김사원 대리님 왜 그러세요 ? 이거 오늘까지 제출해야 하는데 좀 해줄래 ? 네 ? ...      2
# 45  안내놔 많이 몰라 다떨어져서 결제한거 너무 ? 닥치고 폰이나 줄래 혼났어 들켰다가는...      1
# 46  야 너 휴대폰좀 빌려줘봐 안돼 . 지난달에도 휴대폰 요금이 너무 많이 나와서 엄마한...      1
# 47  야 너 휴대폰좀 빌려줘봐 안돼 . 지난달에도 휴대폰 요금이 너무 나와서 엄마한테 혼...      1
# 48  주머니에 내놔봐 있는거 아니에요 잠깐만 지갑을 판단해 ? 좀 거기 맞을래 아니요 잃...      1
# 49  잠깐만 거기 학생 예 ? 저 부르셨너요 ? 그럼 누구겠어 왜부르시죠 내가 지갑을 잃...      1
# 50  잠깐만 학생 예 ? 저 부르셨너요 ? 왜부르시죠 내가 잃어버려서 돈이없다 돈좀 있녀...      1
# 51  내일까지 최선을 . 최선이었어 제발 폰을 . 그걸 새 야 네가 그럼 ? 이걸로 안돼...      1
# 52  얼마 가져왔어 ? 십만원 정도 . 야 이걸로 새 폰을 어떻게 사 이게 최선이었어 ....      1
# 53  얼마 가져왔어 ? 십만원 . 야 이걸로 새 폰을 어떻게 사 이게 . 그럼 최선을 다...      1
# 54  나다 ? 너이마빡에 이마빡 저리치워 한대만 퍽퍽 왜그래 ? ? 뭔소리야 두드리니깐 ...      3
# 55  야 너이마빡에 빛이난다 어 ? 야 한대만 때려보자 퍽 아 흑 왜그래 아팠어 ? 빛이...      3
# 56  너이마빡에 빛이난다 어 야 때려보자 퍽 아 흑 왜그래 아팠어 ? 두드려봤다 가만히있...      3
# 57  남자직원이니까 그러고도 . 세고 부서 거 물 ? 먹는 그래서 힘도 다녀요 저 저만 ...      2
# 58  나씨 정수기 물탱크 좀 갈아주시겠어요 ? 싫습니다 . 물 저만 마시는 것도 아닌데 ...      2
# 59  나씨 정수기 물탱크 좀 갈아주시겠어요 ? 싫습니다 물 저만 마시는 것도 아닌데 매번...      2

# %%
df.head()
# Out:
#    Unnamed: 0  idx  class                                       conversation
# 0           0    1      0  지금 너 스스로를 죽여달라고 애원하는 것인가 ? 아닙니다 . 죄송합니다 . 죽을 거...
# 1           1    2      0  길동경찰서입니다 .  시   분 마트에 폭발물을 설치할거다 . 네 ? 똑바로 들어 ...
# 2           2    3      3  너 되게 귀여운거 알지 ? 나보다 작은 남자는 첨봤어 . 그만해 . 니들 놀리는거 ...
# 3           3    4      1  어이 거기 예 ? ? 너 말이야 너 . 이리 오라고 무슨 일 . 너 옷 좋아보인다 ...
# 4           4    5      1  저기요 혹시 날이 너무 뜨겁잖아요 ? 저희 회사에서 이 선크림 파는데 한 번 손등에...
